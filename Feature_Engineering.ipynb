# %% [markdown]
# # Feature Engineering

# %% [raw]
# we will be performing the below steps
# 1.Handling Missing Values
# 2.Temporal Variables
# 3.Handle Categorical variables:remove rare labels
# 4.Standarddize the values of the variable to ame range

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# to visualize all the column in the dataframe
pd.pandas.set_option('display.max_columns',None)

# %%
dataset=pd.read_csv('train.csv')
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
x=dataset.drop(['Id','SalePrice'],axis=1)
y=dataset['SalePrice']

# %%
from sklearn.model_selection  import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1) #0.1 means 10% of data

# %%
x_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 211           20       RL         83.0    10420   Pave   NaN      Reg
# 1366          60       RL         68.0     9179   Pave   NaN      IR1
# 1124          80       RL          NaN     9125   Pave   NaN      IR1
# 833           20       RL        100.0    10004   Pave   NaN      Reg
# 895           60       RL         71.0     7056   Pave   NaN      Reg
# 405           20       RL          NaN     9991   Pave   NaN      IR1
# 940           90       RL         55.0    12640   Pave   NaN      IR1
# 1337          30       RM        153.0     4118   Pave  Grvl      IR1
# 181           70       RL         54.0     7588   Pave   NaN      Reg
# 1086         160       RM          NaN     1974   Pave   NaN      Reg
# 1320          20       RL         70.0     8400   Pave   NaN      Reg
# 1041          60       RL          NaN     9130   Pave   NaN      Reg
# ...

# %%
#missing values

# %%
feature_nan=[feature for feature in dataset.columns if dataset[feature].isnull().sum()>=1]

# %%
for feature in feature_nan:
    print(" The feature is {} and missing values is {}%".format(feature,np.round(dataset[feature].isnull().mean(),4)))
# Out:
#  The feature is LotFrontage and missing values is 0.1774%
#  The feature is Alley and missing values is 0.9377%
#  The feature is MasVnrType and missing values is 0.0055%
#  The feature is MasVnrArea and missing values is 0.0055%
#  The feature is BsmtQual and missing values is 0.0253%
#  The feature is BsmtCond and missing values is 0.0253%
#  The feature is BsmtExposure and missing values is 0.026%
#  The feature is BsmtFinType1 and missing values is 0.0253%
#  The feature is BsmtFinType2 and missing values is 0.026%
#  The feature is Electrical and missing values is 0.0007%
#  The feature is FireplaceQu and missing values is 0.4726%
#  The feature is GarageType and missing values is 0.0555%
#  The feature is GarageYrBlt and missing values is 0.0555%
#  The feature is GarageFinish and missing values is 0.0555%
#  The feature is GarageQual and missing values is 0.0555%
#  The feature is GarageCond and missing values is 0.0555%
#  The feature is PoolQC and missing values is 0.9952%
# ...

# %%
##Replacing categerical features(fix no of category)

# %%
Categorical_feature=[feature for feature in dataset.columns if dataset[feature].dtypes=='O']

# %%
Categorical_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
data=dataset.copy()
def replace_cat_features(dataset,Categorical_feature):
    data[Categorical_feature]=data[Categorical_feature].fillna('Missing')
    return data

# %%
replace_cat_features(data,Categorical_feature)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 0        1          60       RL         65.0     8450   Pave  Missing
# 1        2          20       RL         80.0     9600   Pave  Missing
# 2        3          60       RL         68.0    11250   Pave  Missing
# 3        4          70       RL         60.0     9550   Pave  Missing
# 4        5          60       RL         84.0    14260   Pave  Missing
# 5        6          50       RL         85.0    14115   Pave  Missing
# 6        7          20       RL         75.0    10084   Pave  Missing
# 7        8          60       RL          NaN    10382   Pave  Missing
# 8        9          50       RM         51.0     6120   Pave  Missing
# 9       10         190       RL         50.0     7420   Pave  Missing
# 10      11          20       RL         70.0    11200   Pave  Missing
# 11      12          60       RL         85.0    11924   Pave  Missing
# ...
